# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
from selenium.webdriver.common.by import By

driver = webdriver.Chrome('C:/Users/Admin/Desktop/jm/chromedriver.exe')  # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("삼겹살") #검색어 이름 넣기
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

# while True:
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#     time.sleep(SCROLL_PAUSE_TIME)

#     new_height = driver.execute_script("return document.body.scrollHeight")
#     if new_height == last_height:
#         try:
#             driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
#         except:
#             break
#     last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")
count = 1
for image in images:
    try:
        if count != 1:
            image.click()
            time.sleep(2)
            imgUrl = driver.find_element(By.XPATH,
                '/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
                "src")
        else:
            image.click()
            time.sleep(2)
            imgUrl = driver.find_element(By.XPATH,
                f'/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div[{count}]/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
                "src")
        urllib.request.urlretrieve(imgUrl, str(count) + ".jpg")
        count = count + 1
    except:
        pass

driver.close()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12040\440854340.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/Admin/Desktop/jm/chromedriver.exe')  # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [3], in <cell line: 54>()
#      51     except:
#      52         pass
# ---> 54 driver.close()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:551, in WebDriver.close(self)
#     542 def close(self) -> None:
#     543     """
#     544     Closes the current window.
#     545
#    (...)
#     549             driver.close()
#     550     """
# --> 551     self.execute(Command.CLOSE)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
# ...

# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
from selenium.webdriver.common.by import By

driver = webdriver.Chrome('C:/Users/Admin/Desktop/jm/chromedriver.exe')  # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("삼겹살") #검색어 이름 넣기
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

# while True:
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#     time.sleep(SCROLL_PAUSE_TIME)

#     new_height = driver.execute_script("return document.body.scrollHeight")
#     if new_height == last_height:
#         try:
#             driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
#         except:
#             break
#     last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")
count = 1
for image in images:
    if count != 1:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.XPATH,
            '/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
            "src")
    else:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.XPATH,
            f'/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div[{count}]/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
            "src")
    urllib.request.urlretrieve(imgUrl, str(count) + ".jpg")
    count = count + 1

driver.close()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12040\1400791075.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/Admin/Desktop/jm/chromedriver.exe')  # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 35>()
#      44         time.sleep(2)
#      45         imgUrl = driver.find_element(By.XPATH,
#      46             f'/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div[{count}]/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
#      47             "src")
# ---> 48     urllib.request.urlretrieve(imgUrl, str(count) + ".jpg")
#      49     count = count + 1
#      51 driver.close()
#
# File ~\anaconda3\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
# ...

# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
from selenium.webdriver.common.by import By

driver = webdriver.Chrome('C:/Users/Admin/Desktop/jm/chromedriver.exe')  # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("삼겹살") #검색어 이름 넣기
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

# while True:
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#     time.sleep(SCROLL_PAUSE_TIME)

#     new_height = driver.execute_script("return document.body.scrollHeight")
#     if new_height == last_height:
#         try:
#             driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
#         except:
#             break
#     last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")
count = 1
for image in images:
    if count != 1:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.XPATH,
            '/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
            "src")
    else:
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element(By.XPATH,
            f'/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div[{count}]/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute(
            "src")
    urllib.request.urlretrieve(imgUrl, str(count) + ".jpg")
    count = count + 1

driver.close()
